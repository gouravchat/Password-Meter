# %%
import pandas as pd

# %%
df = pd.read_csv('password_analysis.csv')

# %%
df['2-gram']
# Out:
# 0        58.175650
# 1       466.501371
# 2        69.493719
# 3        56.392288
# 4        58.441312
#            ...
# 1721     54.389783
# 1722    466.501371
# 1723     56.328753
# 1724     57.958136
# 1725     69.933056
# Name: 2-gram, Length: 1726, dtype: float64

# %%
df['PCFG'].describe()
# Out:
# count    1726.000000
# mean       58.503416
# std         1.515803
# min        43.836680
# 25%        58.885253
# 50%        58.885253
# 75%        58.885253
# max        58.885253
# Name: PCFG, dtype: float64

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'password', '2-gram', '3-gram', '4-gram', '5-gram',
#        'Backoff', 'PCFG'],
#       dtype='object')

# %%
import seaborn as sns
sns.set_theme(style="darkgrid")

def plotFuncHist(df,col):

    plt.figure(figsize = (20,20))
    plt.xlabel("Guess Number",fontsize = 25)
    plt.ylabel("Counts/Frequnecy",fontsize = 25)
    plt.xticks(fontsize = 15)
    plt.yticks(fontsize = 15)
    plt.grid()
    plt.hist(df[col], density = True)
    plt.title(col,fontsize= 20)


plotFuncHist(df,'Backoff')

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(df['2-gram'],cumulative=True)
# Out:
# (array([  5.,  23.,  76., 146., 236., 321., 389., 422., 429., 434.]),
#  array([48.47552405, 50.59708776, 52.71865148, 54.8402152 , 56.96177891,
#         59.08334263, 61.20490635, 63.32647006, 65.44803378, 67.5695975 ,
#         69.69116121]),
#  <a list of 10 Patch objects>)

# %%
with open("check.txt","w") as f:
    f.write("hello"+"\n")
    f.write("I am")
