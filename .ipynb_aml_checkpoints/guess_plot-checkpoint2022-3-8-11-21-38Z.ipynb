# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
pip install zxcvbn
# Out:
# Collecting zxcvbn
#   Downloading zxcvbn-4.4.28.tar.gz (407 kB)
#      |████████████████████████████████| 407 kB 27.5 MB/s eta 0:00:01
# Building wheels for collected packages: zxcvbn
# done
#   Created wheel for zxcvbn: filename=zxcvbn-4.4.28-py2.py3-none-any.whl size=408152 sha256=f3bfc4c61a41429a8aba2b29a8514748034cc1ada7977f172f86515d272b8cc3
#   Stored in directory: /home/azureuser/.cache/pip/wheels/0b/3c/28/4ff6e7734ddddf258f67d4ec3e54ada8a2061ff9808bb71785
# Successfully built zxcvbn
# Installing collected packages: zxcvbn
# Successfully installed zxcvbn-4.4.28
# Note: you may need to restart the kernel to use updated packages.

# %%
from zxcvbn import zxcvbn

results = zxcvbn('myHome2304!')

print(results)
# Out:
# {'password': 'myHome2304!', 'guesses': Decimal('8800000000'), 'guesses_log10': 9.944482672150167, 'sequence': [{'pattern': 'dictionary', 'i': 0, 'j': 1, 'token': 'my', 'matched_word': 'my', 'rank': 13, 'dictionary_name': 'us_tv_and_film', 'reversed': False, 'l33t': False, 'base_guesses': 13, 'uppercase_variations': 1, 'l33t_variations': 1, 'guesses': 50, 'guesses_log10': 1.6989700043360185}, {'pattern': 'dictionary', 'i': 2, 'j': 5, 'token': 'Home', 'matched_word': 'home', 'rank': 145, 'dictionary_name': 'english_wikipedia', 'reversed': False, 'l33t': False, 'base_guesses': 145, 'uppercase_variations': 2, 'l33t_variations': 1, 'guesses': 290, 'guesses_log10': 2.4623979978989556}, {'pattern': 'bruteforce', 'token': '2304!', 'i': 6, 'j': 10, 'guesses': 100000, 'guesses_log10': 5.0}], 'calc_time': datetime.timedelta(0, 0, 1069), 'crack_times_seconds': {'online_throttling_100_per_hour': Decimal('316800000000.0000175859327101'), 'online_no_throttling_10_per_second': Decimal('880000000'), 'offline_slow_hashing_1e4_per_second': Decimal('880000'), 'offline_fast_hashing_1e10_per_second': Decimal('0.88')}, 'crack_times_display': {'online_throttling_100_per_hour': 'centuries', 'online_no_throttling_10_per_second': '27 years', 'offline_slow_hashing_1e4_per_second': '10 days', 'offline_fast_hashing_1e10_per_second': 'less than a second'}, 'score': 3, 'feedback': {'warning': '', 'suggestions': []}}

# %%
df = pd.read_csv('password_analysis.csv')

# %%
df['2-gram']
# Out:
# 0        58.397845
# 1       486.764092
# 2        69.488410
# 3        56.652206
# 4        58.688490
#            ...
# 1721     54.562254
# 1722    486.764092
# 1723     56.542855
# 1724     58.275027
# 1725     69.949843
# Name: 2-gram, Length: 1726, dtype: float64

# %%
df['2-gram'].describe()
# Out:
# count    1726.000000
# mean      192.310989
# std       195.867996
# min        52.494292
# 25%        58.057991
# 50%        66.761242
# 75%       486.764092
# max       486.764092
# Name: 2-gram, dtype: float64

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'password', '2-gram', '3-gram', '4-gram', '5-gram',
#        'Backoff', 'PCFG'],
#       dtype='object')

# %%
import seaborn as sns
sns.set_theme(style="darkgrid")

def plotFuncHist(df,col):

    plt.figure(figsize = (20,20))
    plt.xlabel("Guess Number",fontsize = 25)
    plt.ylabel("Counts",fontsize = 25)
    plt.xticks(fontsize = 25)
    plt.yticks(fontsize = 25)
    plt.grid()
    plt.hist(df[col], bins = 100)
    plt.title(col,fontsize= 20)


plotFuncHist(df,'3-gram')

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(df['2-gram'],cumulative=True)
# Out:
# (array([  5.,  23.,  76., 146., 236., 321., 389., 422., 429., 434.]),
#  array([48.47552405, 50.59708776, 52.71865148, 54.8402152 , 56.96177891,
#         59.08334263, 61.20490635, 63.32647006, 65.44803378, 67.5695975 ,
#         69.69116121]),
#  <a list of 10 Patch objects>)

# %%
with open("check.txt","w") as f:
    f.write("hello"+"\n")
    f.write("I am")
